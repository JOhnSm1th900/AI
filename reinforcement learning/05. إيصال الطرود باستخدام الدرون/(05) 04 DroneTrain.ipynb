# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gymnasium
# مكتبة لاستيراد ملفات الشيفرة
# !pip install nbimporter
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: nbimporter in /usr/local/lib/python3.11/dist-packages (0.3.4)

# %%
# صنف استيراد ملفات الشيفرة
import nbformat

# %%
# مسار ملف الصنف
class_file_path='/content/drive/MyDrive/ملفات الاكواد/05. إيصال الطرود باستخدام الدرون/Classes/DroneEnvironment.ipynb'

# %%
# تحميل ملف شيفرة الصنف
with open(class_file_path) as f:
    notebook = nbformat.read(f, as_version=4)

# %%
# تنفيذ خلايا الشيفرة
for cell in notebook.cells:
    if cell.cell_type == "code":
        try:
            exec(cell.source)
        except Exception as e:
            print(f"Error executing cell: {e}")

# %%
# مثال
# الأبنية
buildings = [
    {'pos': [3, 3, 0], 'size': [5, 5, 5]},
    {'pos': [8, 8, 0], 'size': [1, 1, 1]}
]
# المناطق الممنوعة
prohibited_zones = [
    {'pos': [0, 2, 0], 'size': [2, 4, 4]},
    {'pos': [8, 1, 0], 'size': [2, 2, 5]}
]
# البداية
start_position = [1, 9, 0]
# الهدف
goal_position = [9, 0, 8]

# إنشاء البيئة
env = gym.make("Drone-v0", grid_size=10, start_position=start_position,buildings=buildings, prohibited_zones=prohibited_zones , max_episode_steps=200)

env.reset()
raw_env = env.unwrapped
raw_env.set_goal(goal_position )

# الإظهار
env.render()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac6ee4fe-4049-45f2-a0f4-55e3b031e002" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac6ee4fe-4049-45f2-a0f4-55e3b031e002")) {                    Plotly.newPlot(                        "ac6ee4fe-4049-45f2-a0f4-55e3b031e002",                        [{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[3,8,8,3],"y":[3,3,3,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,8,8,8],"y":[3,8,8,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,3,3,8],"y":[8,8,8,8],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[3,3,3,3],"y":[8,3,3,8],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[1,1,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,9,9,8],"y":[8,8,8,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[9,9,9,9],"y":[8,9,9,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[9,8,8,9],"y":[9,9,9,9],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,8,8,8],"y":[9,8,8,9],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[4,4,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[0,2,2,0],"y":[2,2,2,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[2,2,2,2],"y":[2,6,6,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[2,0,0,2],"y":[6,6,6,6],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[0,0,0,0],"y":[6,2,2,6],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[8,10,10,8],"y":[1,1,1,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[10,10,10,10],"y":[1,3,3,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","name":"Building","showlegend":false,"x":[10,8,8,10],"y":[3,3,3,3],"z":[0,0,5,5],"typ ...

# %%
# دالة لاختيار الفعل باستخدام إبسيلون
def epsilon_greedy(state, q_table, epsilon):
  # إذا كان العدد العشوائي أقل من إبسيلون، نستكشف
  if np.random.rand() < epsilon:
      # اختيار فعل عشوائي
      return env.action_space.sample()
  # إذا كان العدد العشوائي أكبر من إبسيلون، نستخدم المعرفة السابقة
  else:
      # اختيار الفعل الذي له أعلى قيمة
      return np.argmax(q_table[state])

# %%
# دالة التدريب
def train_agent(env):
    # تهبئة جدول القيم
    q_table = np.zeros((env.observation_space.n, env.action_space.n))
    # معاملات خوارزمية التعلم النوعي
    learning_rate = 0.1  # معدل التعلم
    discount_factor = 0.9  # عامل الخصم
    epsilon_start = 1.0  # قيمة إبسيلون للبداية
    epsilon_min = 0.01  # الحد الأدنى لقيمة إبسيلون
    epsilon_decay = 0.999995  # تقليل إبسيلون تدريجيًا مع مرور الحلقات
    # عدد الحلقات التدريبية
    num_episodes = 200000
    epsilon=epsilon_start

      # حلقة التدريب الرئيسية
    for episode in range(num_episodes):
        # إعادة تهيئة البيئة في بداية كل حلقة
        state, info = env.reset()
        done = False
        # المكافأة الإجمالية للحلقة
        total_reward = 0

        # حلقة لتحديث القيم بناءً على الأفعال التي يتم اتخاذها
        while not done:
            # اختيار الفعل
            action = epsilon_greedy(state, q_table, epsilon)
            # تطبيق الفعل
            next_state, reward, terminated, truncated, info = env.step(action)

            # تحديث القيمة في الجدول
            q_table[state, action] = q_table[state, action] + learning_rate * (reward + discount_factor * np.max(q_table[next_state]) - q_table[state, action])
            # الانتقال للحالة التالية
            state = next_state
            # إضافة المكافأة إلى إجمالي مكافآت الحلقة
            total_reward += reward
            # التحقق مما إذا كانت الحلقة قد انتهت
            if terminated or truncated:
                done = True  # نهاية الحلقة
        # تقليل إبسيلون مع تقدم الحلقات
        epsilon = max(epsilon_min, epsilon * epsilon_decay )

        # طباعة التقدم كل 10000 حلقة لتتبع الأداء
        if (episode + 1) % 10000 == 0:
            print(f"Episode {episode+1}/{num_episodes}, Total Reward: {total_reward}, Epsilon: {epsilon:.4f}")
    return q_table

# %%
# تدريب الدرون
q_table = train_agent(env)
# Out:
# Episode 10000/200000, Total Reward: -4098, Epsilon: 0.9512
# Episode 20000/200000, Total Reward: -2713, Epsilon: 0.9048
# Episode 30000/200000, Total Reward: 608, Epsilon: 0.8607
# Episode 40000/200000, Total Reward: -463, Epsilon: 0.8187
# Episode 50000/200000, Total Reward: -2822, Epsilon: 0.7788
# Episode 60000/200000, Total Reward: -4007, Epsilon: 0.7408
# Episode 70000/200000, Total Reward: -3019, Epsilon: 0.7047
# Episode 80000/200000, Total Reward: -2964, Epsilon: 0.6703
# Episode 90000/200000, Total Reward: -2476, Epsilon: 0.6376
# Episode 100000/200000, Total Reward: -3119, Epsilon: 0.6065
# Episode 110000/200000, Total Reward: 632, Epsilon: 0.5769
# Episode 120000/200000, Total Reward: -3514, Epsilon: 0.5488
# Episode 130000/200000, Total Reward: 254, Epsilon: 0.5220
# Episode 140000/200000, Total Reward: -3515, Epsilon: 0.4966
# Episode 150000/200000, Total Reward: 881, Epsilon: 0.4724
# Episode 160000/200000, Total Reward: -2525, Epsilon: 0.4493
# Episode 170000/200000, Total Reward: 893, Epsilon: 0.4274
# Episode 180000/200000, Total Reward: -2823, Epsilon: 0.4066
# Episode 190000/200000, Total Reward: -1784, Epsilon: 0.3867
# Episode 200000/200000, Total Reward: -2921, Epsilon: 0.3679

# %%
import pickle
def save_q_table_and_env(q_table, env, q_table_file, env_file):
    # القيم النوعية
    with open(q_table_file, 'wb') as f:
        pickle.dump(q_table, f)
    # البيئة
    with open(env_file, 'wb') as f:
        pickle.dump(env, f)

# %%
# مسار مجلد العمل
working_folder='/content/drive/MyDrive/ملفات الاكواد/RLModels'
# مسار ملف جدول القيم
q_table_Drone_path = working_folder + "q_table_Drone.pkl"
# مسار ملف البيئة
env_pkl_Drone_path = working_folder + "env_pkl_Drone.pkl"

# %%
save_q_table_and_env(q_table, env,q_table_Drone_path, env_pkl_Drone_path)
