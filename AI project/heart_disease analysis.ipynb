# %% [markdown]
# Data exploration and cleaning

# %%
import pandas as pd
from click import password_option

# مثال: تحميل بيانات أمراض القلب
df = pd.read_csv('heart_disease_uci.csv')  # ملف CSV من مصدر Kaggle أو UCI
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 748
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        299 non-null    int64
#  1   age       299 non-null    int64
#  2   sex       299 non-null    object
#  3   dataset   299 non-null    object
#  4   cp        299 non-null    object
#  5   trestbps  299 non-null    float64
#  6   chol      299 non-null    float64
#  7   fbs       299 non-null    object
#  8   restecg   299 non-null    object
#  9   thalch    299 non-null    float64
#  10  exang     299 non-null    object
#  11  oldpeak   299 non-null    float64
#  12  slope     299 non-null    object
#  13  ca        299 non-null    float64
#  14  thal      299 non-null    object
#  15  num       299 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 39.7+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  299.000000  299.000000  299.000000  299.000000  299.000000  299.000000
# mean   153.872910   54.521739  131.715719  246.785953  149.327759    1.058528
# std     95.896287    9.030264   17.747751   52.532582   23.121062    1.162769
# min      1.000000   29.000000   94.000000  100.000000   71.000000    0.000000
# 25%     75.500000   48.000000  120.000000  211.000000  132.500000    0.000000
# 50%    151.000000   56.000000  130.000000  242.000000  152.000000    0.800000
# 75%    227.500000   61.000000  140.000000  275.500000  165.500000    1.600000
# max    749.000000   77.000000  200.000000  564.000000  202.000000    6.200000
#
#                ca         num
# count  299.000000  299.000000
# mean     0.672241    0.946488
# std      0.937438    1.230409
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    2.000000
# max      3.000000    4.000000

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %% [markdown]
# Data analaysis and visualization

# %% [markdown]
# analyze and visualize the relationship between the numeric values and the disease

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure num is numeric and within 0–4
print(sorted(df['num'].unique()))  # Should show [0,1,2,3,4]

df['num'] = pd.to_numeric(df['num'], errors='coerce')

features = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak']
sns.set(style='whitegrid')

for feat in features:
    fig, ax = plt.subplots(figsize=(6, 4))

    if feat == 'fbs':
        # Proportion of num classes at fbs levels 0 and 1
        data = df.groupby(['fbs', 'num']).size().unstack(fill_value=0)
        prop = data.div(data.sum(axis=1), axis=0).T  # num on rows

        sns.lineplot(data=prop, markers=True, ax=ax)
        ax.set_xlabel('Fasting Blood Sugar >120 mg/dL (fbs)')
        ax.set_ylabel('Proportion per Disease Severity')
        ax.set_title(f'Proportion by {feat} across Disease Severity')
        ax.set_yticks(range(0, 5))  # show all num levels
        ax.legend(title='fbs', bbox_to_anchor=(1.05, 1), loc='upper left')
    else:
        # Mean feature value across num levels
        agg = df.groupby('num')[feat].mean()
        sns.lineplot(x=agg.values, y=agg.index, marker='o', ax=ax)
        ax.set_xlabel(f'Mean {feat}')
        ax.set_ylabel('Disease Severity (num)')
        ax.set_title(f'{feat} vs Disease Severity')
        ax.set_yticks(range(0, 5))  # ensure ticks from 0 to 4

    plt.tight_layout()
    plt.show()
# Out:
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4)]

# %% [markdown]
# analyze and visualize the relationship between the non-numeric values and the disease

# %%
sns.set_theme(style="whitegrid")

for feat in ['restecg','slope','ca','thal','cp','exang','sex','dataset']:
    g = sns.catplot(
        data=df,
        x=feat,
        y='num',
        kind='bar',
        hue=feat,             # assign hue explicitly
        palette='Set2',
        errorbar=None,        # replace deprecated ci
        legend=False,         # suppress redundant legend
        height=5, aspect=1.2
    )
    g.set_axis_labels(feat, 'Disease Severity (num)')
    g.ax.set_title(f'{feat} vs num (mean num per category)')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ML & DL Model

# %%
# turning non-numeric values to numbers
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in ['sex', 'exang', 'fbs', 'cp', 'restecg', 'slope', 'ca', 'thal', 'dataset']:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
df.head()
# Out:
#    id  age  sex  dataset  cp  trestbps   chol  fbs  restecg  thalch  exang  \
# 0   1   63    1        0   3     145.0  233.0    1        0   150.0      0
# 1   2   67    1        0   0     160.0  286.0    0        0   108.0      1
# 2   3   67    1        0   0     120.0  229.0    0        0   129.0      1
# 3   4   37    1        0   2     130.0  250.0    0        1   187.0      0
# 4   5   41    0        0   1     130.0  204.0    0        0   172.0      0
#
#    oldpeak  slope  ca  thal  num
# 0      2.3      0   0     0    0
# 1      1.5      1   3     1    2
# 2      2.6      1   2     2    1
# 3      3.5      0   0     1    0
# 4      1.4      2   0     1    0

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = df[df['num'].isin([0,1,2,3,4])]
X = df.drop('num', axis=1).values
y = df['num'].values

# use scaler for standardized data for DL

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# train the data

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# use DL model

inp = Input(shape=(X_train.shape[1],))
x = Dense(64, activation='relu')(inp)
x = Dense(32, activation='relu')(x)
feature_layer = Dense(16, activation='relu')(x)

# Add a dummy classification head for training
out = Dense(5, activation='softmax')(feature_layer)

dl_model = Model(inputs=inp, outputs=out)

# Compiling the model

dl_model.compile(optimizer=Adam(1e-3),
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

dl_model.fit(X_train, y_train, epochs=30, batch_size=32,
             validation_split=0.1, verbose=2)

# Extract features
extractor = Model(inputs=inp, outputs=feature_layer)
X_train_dl = extractor.predict(X_train)
X_test_dl  = extractor.predict(X_test)
# Out:
# Epoch 1/30
# 7/7 - 1s - 165ms/step - accuracy: 0.2791 - loss: 1.6035 - val_accuracy: 0.5417 - val_loss: 1.5022
# Epoch 2/30
# 7/7 - 0s - 14ms/step - accuracy: 0.4791 - loss: 1.4968 - val_accuracy: 0.4583 - val_loss: 1.4527
# Epoch 3/30
# 7/7 - 0s - 14ms/step - accuracy: 0.5535 - loss: 1.4147 - val_accuracy: 0.4167 - val_loss: 1.3990
# Epoch 4/30
# 7/7 - 0s - 14ms/step - accuracy: 0.5628 - loss: 1.3292 - val_accuracy: 0.4583 - val_loss: 1.3294
# Epoch 5/30
# 7/7 - 0s - 13ms/step - accuracy: 0.5814 - loss: 1.2476 - val_accuracy: 0.4583 - val_loss: 1.2494
# Epoch 6/30
# 7/7 - 0s - 13ms/step - accuracy: 0.5953 - loss: 1.1527 - val_accuracy: 0.4583 - val_loss: 1.1714
# Epoch 7/30
# 7/7 - 0s - 14ms/step - accuracy: 0.6000 - loss: 1.0739 - val_accuracy: 0.4583 - val_loss: 1.1195
# Epoch 8/30
# 7/7 - 0s - 14ms/step - accuracy: 0.6093 - loss: 1.0131 - val_accuracy: 0.4583 - val_loss: 1.0866
# Epoch 9/30
# 7/7 - 0s - 12ms/step - accuracy: 0.6047 - loss: 0.9672 - val_accuracy: 0.5833 - val_loss: 1.0698
# Epoch 10/30
# 7/7 - 0s - 13ms/step - accuracy: 0.6047 - loss: 0.9306 - val_accuracy: 0.5833 - val_loss: 1.0577
# Epoch 11/30
# 7/7 - 0s - 13ms/step - accuracy: 0.6326 - loss: 0.8977 - val_accuracy: 0.5833 - val_loss: 1.0443
# Epoch 12/30
# 7/7 - 0s - 12ms/step - accuracy: 0.6326 - loss: 0.8674 - val_accuracy: 0.5833 - val_loss: 1.0359
# Epoch 13/30
# 7/7 - 0s - 13ms/step - accuracy: 0.6558 - loss: 0.8386 - val_accuracy: 0.5833 - val_loss: 1.0271
# Epoch 14/30
# 7/7 - 0s - 12ms/step - accuracy: 0.6884 - loss: 0.8125 - val_accuracy: 0.5833 - val_loss: 1.0233
# Epoch 15/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7023 - loss: 0.7867 - val_accuracy: 0.5833 - val_loss: 1.0264
# Epoch 16/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7209 - loss: 0.7650 - val_accuracy: 0.5833 - val_loss: 1.0271
# Epoch 17/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7302 - loss: 0.7418 - val_accuracy: 0.5417 - val_loss: 1.0373
# Epoch 18/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7256 - loss: 0.7227 - val_accuracy: 0.5417 - val_loss: 1.0414
# Epoch 19/30
# 7/7 - 0s - 14ms/step - accuracy: 0.7256 - loss: 0.7043 - val_accuracy: 0.5417 - val_loss: 1.0553
# Epoch 20/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7349 - loss: 0.6886 - val_accuracy: 0.5417 - val_loss: 1.0569
# Epoch 21/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7442 - loss: 0.6722 - val_accuracy: 0.5417 - val_loss: 1.0668
# Epoch 22/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7488 - loss: 0.6570 - val_accuracy: 0.5417 - val_loss: 1.0711
# Epoch 23/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7581 - loss: 0.6434 - val_accuracy: 0.5000 - val_loss: 1.0732
# Epoch 24/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7628 - loss: 0.6305 - val_accuracy: 0.5000 - val_loss: 1.0829
# Epoch 25/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7628 - loss: 0.6187 - val_accuracy: 0.5000 - val_loss: 1.0964
# Epoch 26/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7628 - loss: 0.6061 - val_accuracy: 0.5000 - val_loss: 1.0970
# Epoch 27/30
# 7/7 - 0s - 11ms/step - accuracy: 0.7628 - loss: 0.5947 - val_accuracy: 0.5000 - val_loss: 1.1087
# Epoch 28/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7628 - loss: 0.5828 - val_accuracy: 0.5000 - val_loss: 1.1182
# Epoch 29/30
# 7/7 - 0s - 13ms/step - accuracy: 0.7814 - loss: 0.5713 - val_accuracy: 0.5000 - val_loss: 1.1173
# Epoch 30/30
# 7/7 - 0s - 12ms/step - accuracy: 0.7814 - loss: 0.5593 - val_accuracy: 0.5000 - val_loss: 1.1220
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
# fuse normal ML with DL by concatenating raw (scaled) features with learned DL features

X_train_comb = np.hstack([X_train, X_train_dl])
X_test_comb  = np.hstack([X_test, X_test_dl])

# %%
# Random Forest on combined features

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_comb, y_train)

y_pred = rf.predict(X_test_comb)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# Missing classes: {np.int64(4)}
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        32
#            1       0.45      0.45      0.45        11
#            2       0.17      0.14      0.15         7
#            3       0.33      0.43      0.38         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.65        60
#    macro avg       0.37      0.39      0.38        60
# weighted avg       0.61      0.65      0.63        60

# %%
# implementing stacking ensemble

from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

base_estimators = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('svm', SVC(probability=True, random_state=42))
]
meta = LogisticRegression()
stack = StackingClassifier(estimators=base_estimators,
                           final_estimator=meta, cv=5)

stack.fit(X_train_comb, y_train)
print(classification_report(y_test, stack.predict(X_test_comb), zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90        32
#            1       0.30      0.27      0.29        11
#            2       0.00      0.00      0.00         7
#            3       0.44      0.57      0.50         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.62        60
#    macro avg       0.32      0.36      0.34        60
# weighted avg       0.56      0.62      0.59        60

# %%
# saving models using joblib

import joblib

dl_model.save('models/dl_model.keras')
joblib.dump(rf, 'models/rf_model.joblib', compress=3)
joblib.dump(scaler, 'models/scaler.joblib')
# Out:
# ['models/scaler.joblib']
