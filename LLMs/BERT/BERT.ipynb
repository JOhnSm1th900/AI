# %%
model_name = 'nlptown/bert-base-multilingual-uncased-sentiment'

# %%
pip install Transformers
# Out:
# Requirement already satisfied: Transformers in c:\users\eyad3\anaconda3\lib\site-packages (4.34.0)
# Requirement already satisfied: filelock in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\eyad3\anaconda3\lib\site-packages (from Transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\eyad3\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->Transformers) (2023.9.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\eyad3\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->Transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\eyad3\anaconda3\lib\site-packages (from tqdm>=4.27->Transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->Transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->Transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->Transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->Transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained(model_name)

model = TFBertForSequenceClassification.from_pretrained(model_name)
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at nlptown/bert-base-multilingual-uncased-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
text = "I like my job"

inputs = tokenizer(text)
print(inputs)

input_ids = inputs['input_ids']

predictions = model.predict([input_ids])

logits = predictions.logits

import numpy as np

predicted_class = np.argmax(logits)
predicted_class
# Out:
# {'input_ids': [101, 151, 11531, 11153, 19594, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1]}
# 1/1 [==============================] - 5s 5s/step
# 3

# %%
sentiment_mapping = {
    0: 'very negative',
    1: 'negative',
    2: 'neutral',
    3: 'positive',
    4: 'very positive'
}

predicted_sentiment = sentiment_mapping[predicted_class]
print("The text is predicted to have a sentiment: {}".format(predicted_sentiment))
# Out:
# The text is predicted to have a sentiment: positive

# %%
text = "I hate my job"

inputs = tokenizer(text, return_tensors='tf')

input_ids = inputs['input_ids']

predictions = model.predict([input_ids])

logits = predictions.logits

predicted_class = np.argmax(logits)
print(logits)

predicted_sentiment = sentiment_mapping[predicted_class]
print("The text is predicted to have a sentiment: {}".format(predicted_sentiment))
# Out:
# 1/1 [==============================] - 0s 52ms/step
# [[ 2.9380844   1.6215168  -0.16542505 -1.9236571  -1.9499079 ]]
# The text is predicted to have a sentiment: very negative

# %%
import pandas as pd

csv_file = '../IMDB Dataset.csv'

df = pd.read_csv(csv_file)

df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
first_5_rows = df.head(5)

first_5_rows
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import numpy as np

sentiment_mapping = {
    0: 'very negative',
    1: 'negative',
    2: 'neutral',
    3: 'positive',
    4: 'very positive'
}


first_5_rows_copy = first_5_rows.copy()


predicted_sentiments = []


for title in first_5_rows_copy['review']:

    inputs = tokenizer(title,)
    

    input_ids = inputs['input_ids']
    

    predictions = model.predict([input_ids])
    

    logits = predictions.logits
    

    predicted_class = np.argmax(logits)
    print("predicted id: ", predicted_class)

    predicted_sentiment = sentiment_mapping[predicted_class]
    

    predicted_sentiments.append(predicted_sentiment)


first_5_rows_copy['predicted_sentiment'] = predicted_sentiments


first_5_rows_copy
# Out:
# 1/1 [==============================] - 0s 467ms/step
# predicted id:  2
# 1/1 [==============================] - 0s 251ms/step
# predicted id:  4
# 1/1 [==============================] - 0s 253ms/step
# predicted id:  3
# 1/1 [==============================] - 0s 247ms/step
# predicted id:  2
# 1/1 [==============================] - 0s 437ms/step
# predicted id:  3
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#   predicted_sentiment
# 0             neutral
# 1       very positive
# 2            positive
# 3             neutral
# 4            positive

# %%
import pandas as pd

csv_file = 'arabic_review.csv'

df = pd.read_csv(csv_file)

df
# Out:
#     ID                                               Feed Sentiment
# 0    1  الحلو انكم بتحكوا على اساس انو الاردن ما فيه ف...  Negative
# 1    2                            كله رائع بجد ربنا يكرمك  Positive
# 2    3     ابشرك فيه تحسن ولله الحمد باذن الله يرجع قريبا  Positive
# 3    4     ابو الشباب راعي العود ليش ماوزنه في البيت غباء  Negative
# 4    5        ابو معيتق قطع اوتار العود وقال السلام عليكم  Negative
# 5    6                          اترك ما تهوى لاجل من تخشى  Positive
# 6    7    اتصور لو ظليت ما اتعلق احسن لانه تعليقاتك مقرفه  Negative
# 7    8                          اتفه على هيك برنامج عالمي  Negative
# 8    9     اتقوا الله فينا بكفي رفع اسعار الرواتب بالحضيض  Negative
# 9   10                          اجتماع حواء اكيد في خرفنه  Negative
# 10  11  اجل الاخير واضح انو بيمثل وتمثيلو خام هو والا معو  Negative
# 11  12                      احب الله تعالى و رسوله الكريم  Positive
# 12  13                       احتمال ما يشارك الليو البايخ  Negative
# 13  14                                  احس انه يفطر حشيش  Negative
# 14  15                     احسن اظن بالله وتوكل عليه وحده  Positive
# 15  16               احسن شيء العمل الذي يؤدي للاستمراريه  Positive
# 16  17  احسنت  وصفت ما يدور او يجول في راس كل شاب ملتز...  Positive
# 17  18                                احسنت كلام دقيق جدا  Positive
# 18  19  احسنوا الظن وثقوا بما عند الله وتوكلوا عليه لا...  Positive
# 19  20                            احقر من هيك خيانه ما في  Negative
# 20  21                  احلى اشي الواحد يوكل بدون ما يطبخ  Positive
# 21  22           احلى اشي في الحياه الاستقرار مع زوج صالح  Positive
# 22  23                  احلى شىء النهايه الباقيه صح كلامك  Positive
# 23  24                    احلى صباح من احلى شيخ في العالم  Positive
# 24  25  احمد الله تعالى ان اولادي لايدرسون في مدارس ال...  Negative
# 25  26                  احيانا الوحده تزيل بعضا من الهموم  Positive
# 26  27                      احيانا يكون الفشل دافع للنجاح  Positive
# 27  28                         اخ يا بطني عورني من الضحكك  Negative
# 28  29                                        اخبار مسخره  Negative
# 29  30  اخر همي اني اتناقش مع اي كائن حي اواتجادل بذات...  Negative
# 30  31  اخر واحد اش فيه مجنون المفرووض اللجنه تمنع الم...  Negative
# 31  32                                     اخر واحد مهستر  Negative
# 32  33                                  اخرس صحيح ما تفهم  Negative

# %%
first_5_rows = df.head(5)

first_5_rows
# Out:
#    ID                                               Feed Sentiment
# 0   1  الحلو انكم بتحكوا على اساس انو الاردن ما فيه ف...  Negative
# 1   2                            كله رائع بجد ربنا يكرمك  Positive
# 2   3     ابشرك فيه تحسن ولله الحمد باذن الله يرجع قريبا  Positive
# 3   4     ابو الشباب راعي العود ليش ماوزنه في البيت غباء  Negative
# 4   5        ابو معيتق قطع اوتار العود وقال السلام عليكم  Negative

# %%
import numpy as np

sentiment_mapping = {
    0: 'very negative',
    1: 'negative',
    2: 'neutral',
    3: 'positive',
    4: 'very positive'
}

first_5_rows_copy = first_5_rows.copy()

predicted_sentiments = []

for title in first_5_rows_copy['Feed']:

    inputs = tokenizer(title,)
    
    input_ids = inputs['input_ids']
    
    predictions = model.predict([input_ids])
    
    logits = predictions.logits
    
    predicted_class = np.argmax(logits)
    print("predicted id: ", predicted_class)

    predicted_sentiment = sentiment_mapping[predicted_class]
    
    predicted_sentiments.append(predicted_sentiment)

first_5_rows_copy['predicted_sentiment'] = predicted_sentiments

first_5_rows_copy
# Out:
# 1/1 [==============================] - 0s 280ms/step
# predicted id:  0
# 1/1 [==============================] - 0s 85ms/step
# predicted id:  4
# 1/1 [==============================] - 0s 95ms/step
# predicted id:  4
# 1/1 [==============================] - 0s 91ms/step
# predicted id:  4
# 1/1 [==============================] - 0s 87ms/step
# predicted id:  4
#    ID                                               Feed Sentiment  \
# 0   1  الحلو انكم بتحكوا على اساس انو الاردن ما فيه ف...  Negative
# 1   2                            كله رائع بجد ربنا يكرمك  Positive
# 2   3     ابشرك فيه تحسن ولله الحمد باذن الله يرجع قريبا  Positive
# 3   4     ابو الشباب راعي العود ليش ماوزنه في البيت غباء  Negative
# 4   5        ابو معيتق قطع اوتار العود وقال السلام عليكم  Negative
#
#   predicted_sentiment
# 0       very negative
# 1       very positive
# 2       very positive
# 3       very positive
# 4       very positive

# %%
pip install camel-tools
# Out:
# Requirement already satisfied: camel-tools in c:\users\eyad3\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: future in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (0.18.3)
# Requirement already satisfied: six in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (1.16.0)
# Requirement already satisfied: docopt in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (0.6.2)
# Requirement already satisfied: cachetools in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (5.3.1)
# Requirement already satisfied: numpy in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (1.24.3)
# Requirement already satisfied: scipy in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (1.11.1)
# Requirement already satisfied: pandas in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (2.0.3)
# Requirement already satisfied: scikit-learn in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (1.3.0)
# Requirement already satisfied: dill in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (0.3.6)
# Requirement already satisfied: torch>=1.3 in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (2.1.0+cu118)
# Requirement already satisfied: transformers>=3.0.2 in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (4.34.0)
# Requirement already satisfied: editdistance in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (0.6.2)
# Requirement already satisfied: requests in c:\users\eyad3\anaconda3\lib\site-packages (from camel-tools) (2.31.0)
# Requirement already satisfied: filelock in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (4.7.1)
# Requirement already satisfied: sympy in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (1.11.1)
# Requirement already satisfied: networkx in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (3.1)
# Requirement already satisfied: jinja2 in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\eyad3\anaconda3\lib\site-packages (from torch>=1.3->camel-tools) (2023.9.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (0.17.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (2022.7.9)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\eyad3\anaconda3\lib\site-packages (from transformers>=3.0.2->camel-tools) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eyad3\anaconda3\lib\site-packages (from pandas->camel-tools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eyad3\anaconda3\lib\site-packages (from pandas->camel-tools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\eyad3\anaconda3\lib\site-packages (from pandas->camel-tools) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->camel-tools) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->camel-tools) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->camel-tools) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eyad3\anaconda3\lib\site-packages (from requests->camel-tools) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\eyad3\anaconda3\lib\site-packages (from scikit-learn->camel-tools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\eyad3\anaconda3\lib\site-packages (from scikit-learn->camel-tools) (2.2.0)
# Requirement already satisfied: colorama in c:\users\eyad3\anaconda3\lib\site-packages (from tqdm>=4.27->transformers>=3.0.2->camel-tools) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eyad3\anaconda3\lib\site-packages (from jinja2->torch>=1.3->camel-tools) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\eyad3\anaconda3\lib\site-packages (from sympy->torch>=1.3->camel-tools) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from camel_tools.sentiment import SentimentAnalyzer

model_name = SentimentAnalyzer("CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment")
sentences = ['أنا أكره عملي']
model_name.predict(sentences)
# Out:
# ['negative']

# %%
sentences = ['أنا أحب عملي']
model_name.predict(sentences)
# Out:
# ['positive']

# %%
import numpy as np

first_5_rows_copy = first_5_rows.copy()

predicted_sentiments = []

for title in first_5_rows_copy['Feed']:

    predictions = model_name.predict([title])
    
    predicted_sentiments.append(predictions)

first_5_rows_copy['predicted_sentiment'] = predicted_sentiments

first_5_rows_copy
# Out:
#    ID                                               Feed Sentiment  \
# 0   1  الحلو انكم بتحكوا على اساس انو الاردن ما فيه ف...  Negative
# 1   2                            كله رائع بجد ربنا يكرمك  Positive
# 2   3     ابشرك فيه تحسن ولله الحمد باذن الله يرجع قريبا  Positive
# 3   4     ابو الشباب راعي العود ليش ماوزنه في البيت غباء  Negative
# 4   5        ابو معيتق قطع اوتار العود وقال السلام عليكم  Negative
#
#   predicted_sentiment
# 0          [negative]
# 1          [positive]
# 2          [positive]
# 3          [negative]
# 4          [negative]
